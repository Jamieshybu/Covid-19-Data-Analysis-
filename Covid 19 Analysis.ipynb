# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jamie\Downloads\archive\Covid Data.csv")
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(812049)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df.shape
# Out:
# (236526, 21)

# %%
df.dtypes
# Out:
# USMER                   int64
# MEDICAL_UNIT            int64
# SEX                     int64
# PATIENT_TYPE            int64
# DATE_DIED                 str
# INTUBED                 int64
# PNEUMONIA               int64
# AGE                     int64
# PREGNANT                int64
# DIABETES                int64
# COPD                    int64
# ASTHMA                  int64
# INMSUPR                 int64
# HIPERTENSION            int64
# OTHER_DISEASE           int64
# CARDIOVASCULAR          int64
# OBESITY                 int64
# RENAL_CHRONIC           int64
# TOBACCO                 int64
# CLASIFFICATION_FINAL    int64
# ICU                     int64
# dtype: object

# %%
df.describe()
# Out:
#                USMER   MEDICAL_UNIT            SEX   PATIENT_TYPE  \
# count  236526.000000  236526.000000  236526.000000  236526.000000
# mean        1.512337       7.634230       1.547521       1.577712
# std         0.499849       3.661318       0.497738       0.493925
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       4.000000       1.000000       1.000000
# 50%         2.000000       6.000000       2.000000       2.000000
# 75%         2.000000      12.000000       2.000000       2.000000
# max         2.000000      13.000000       2.000000       2.000000
#
#              INTUBED      PNEUMONIA            AGE       PREGNANT  \
# count  236526.000000  236526.000000  236526.000000  236526.000000
# mean       44.238401       4.525765      52.620274      54.794826
# std        47.394072      16.731469      19.318869      47.225449
# min         1.000000       1.000000       0.000000       1.000000
# ...

# %%
df["SEX"].value_counts()
# Out:
# SEX
# 2    129503
# 1    107023
# Name: count, dtype: int64

# %%
df["PATIENT_TYPE"].value_counts()
# Out:
# PATIENT_TYPE
# 2    136644
# 1     99882
# Name: count, dtype: int64

# %%
df.groupby("SEX")["AGE"].mean()
# Out:
# SEX
# 1    51.863151
# 2    53.245971
# Name: AGE, dtype: float64

# %%
# Out:
# SEX
# 1    107023
# 2    129503
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df["SEX"].value_counts()
# Out:
# SEX
# 2    129503
# 1    107023
# Name: count, dtype: int64

# %%
#People getting affected by diseases based on their age

# %%
plt.hist(df['AGE'])
# Out:
# (array([7.3450e+03, 1.1188e+04, 3.0226e+04, 4.4541e+04, 5.7004e+04,
#         4.9316e+04, 2.8565e+04, 7.8530e+03, 4.5800e+02, 3.0000e+01]),
#  array([  0. ,  12.1,  24.2,  36.3,  48.4,  60.5,  72.6,  84.7,  96.8,
#         108.9, 121. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
plt.scatter(df['AGE'], df['MEDICAL_UNIT'])

# %%
plt.scatter(df['AGE'], df['DIABETES'])

# %%
import seaborn as sns

# %%
sns.countplot(x='TOBACCO', data=df,hue='TOBACCO')
# Out:
# <Axes: xlabel='TOBACCO', ylabel='count'>

# %%
#Gender Distribution

# %%
df['SEX'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SEX'>

# %%
df['SEX'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df['PATIENT_TYPE'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.show()

# %%
plt.plot(df['AGE'].head(100))

# %%
import seaborn as sns

# %%
sns.countplot(x='SEX', data=df,hue='SEX')
# Out:
# <Axes: xlabel='SEX', ylabel='count'>

# %%
plt.hist(df['AGE'])
# Out:
# (array([7.3450e+03, 1.1188e+04, 3.0226e+04, 4.4541e+04, 5.7004e+04,
#         4.9316e+04, 2.8565e+04, 7.8530e+03, 4.5800e+02, 3.0000e+01]),
#  array([  0. ,  12.1,  24.2,  36.3,  48.4,  60.5,  72.6,  84.7,  96.8,
#         108.9, 121. ]),
#  <BarContainer object of 10 artists>)
